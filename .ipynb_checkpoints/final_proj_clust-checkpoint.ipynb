# %%
import numpy as np
import pandas as pd
import seaborn as sns
import math
import random
import matplotlib.pyplot as plt
import sys
import json
import prince
from datetime import timedelta, date, datetime
from mpl_toolkits.mplot3d import Axes3D
# from kmodes.kprototypes import KPrototypes
from sklearn.preprocessing import StandardScaler
# from kneed import KneeLocator
from sklearn.cluster import KMeans
# from light_famd import MCA,FAMD
from scipy import stats

# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import os
path = os.getcwd() + '/DataForClusterization.csv'
data = pd.read_csv(path)
data
# Out:
#      Unnamed: 0        Date   Week_Day      Month  User_Activity  Food_Count  \
# 0             0  2014-09-14     Sunday  September             56         164
# 1             1  2014-09-15     Monday  September            280         909
# 2             2  2014-09-16    Tuesday  September            279         924
# 3             3  2014-09-17  Wednesday  September            274         861
# 4             4  2014-09-18   Thursday  September            382        1342
# ..          ...         ...        ...        ...            ...         ...
# 203         203  2015-04-05     Sunday      April            515        1766
# 204         204  2015-04-06     Monday      April            574        1940
# 205         205  2015-04-07    Tuesday      April            351        1276
# 206         206  2015-04-08  Wednesday      April            132         480
# 207         207  2015-04-09   Thursday      April             17          47
#
# ...

# %% [markdown]
# პროექტის პირველ ნაწილში (ანუ ფაილში final_proj.ipynb) არსებული დატა ვთარგმნეთ და გარდავქმენით ჩვნთვის სასურველ მონაცემებად. არსებული json ფაილიდან მივიღეთ csv ფაილი სახელად DataForClusterization, რომელიც სახელიდან გამომდინარე შეიცავს ყველა იმ ინფორმაციას რაც საჭიროა ჩვენი სამული ამოცანის გადასაჭრელად.
#
# კლასტერიზაციის კლასიკური ამოცანის გადასაჭელად საჭირო null value-ების ამოღება და სხვა ადეკვატური მნიშვნელობებით ჩანაცვლება ამ შემთხვევაში აღარ დაგვჭირდება, რადგან ეგ ამოცანის პირველ ნაწილში უზრუნველვყავით და ახლანდელი data, რომელიც DataForClusterization-დან წამოვიღეთ სუფთაა და მაქსიმუმ აუთლეირების ამოღება დასჭირდეს, რომელსაც საჭიროების შემთხვევაში ვიზამთ.

# %% [markdown]
# ### დავპლოტოთ ჩვენი მონაცემები User_Activity-ების ჭრილში რაც საწყის ეტაპზე მარტივი მსჯელობის წარმოების შესაძლებლობას გვაძლევს
#
# როგორც ვხედავთ მომხმარებელტა აქტივობა ჩვენი მონაცემების დაახლოებით შუაში, ანუ 100-105 დღის შუალედში მკაფიოდ ეცემა. თუ დავაკვირდებით საწყის და საბოლოო თარიღებს და დიაპაზონს 14 სექტემბერი - 9 მაისი, აღმოვაჩენთ რომ ეს ცავარდა ზუსტად ემთხვევა დეკემბრის ბოლოსა და იანვრის დასაწყისს, ანუ შობა-ახალი წლის პერიოდში, აპლიკაციის მომხმარებელი მაქსიმალურად გაზარმაცდა და აღარ შეჰყავდათ მონაცემები აპლიკაციაში, მსგავსი დამოკიდებულება საახალწლო პერიოდში და ზოგადად დღესასწაულებზე საკმაოდ საინტერესო არმოჩნდა ჩვენთვის რასაც სამომავლოდაც დავაკვირდებით.

# %%
plt.figure(figsize=(15,5))
plt.plot(data['User_Activity'], color='blue')
plt.ylabel('User_Activity')
plt.title('Days')
# Out:
# Text(0.5, 1.0, 'Days')

# %%
def getDayNum(Day):
    if(Day == "Monday"): return 1
    if(Day == "Tuesday"): return 2
    if(Day == "Wednesday"): return 3
    if(Day == "Thursday"): return 4
    if(Day == "Friday"): return 5
    if(Day == "Saturday"): return 6
    if(Day == "Sunday"): return 7

# %% [markdown]
# #### დასახული ამოცანის გადასაჭრელად და მონაცემების გასააზრებლად გადავწყვიტეთ არსებული მონაცემების დახლეჩვა და მათი ნაწილ-ნაწილ გაანალიზება.
#
# პირველ რიგში განვიხილავთ მომხმარებლის მიერ შეყვანილი მონაცემების ჭამურ მნიშვნელობებს დღეების ჭრილში. ანუ პირველ დღეს ჯამში რამდენი ცხიმი მოიხმარეს მომმხმარებლება, რამდენი სოდიუმი და ა.შ.

# %%
data_point= {}
data_point['total_calories'] = data["total_calories"]
data_point['total_carbs'] = data["total_carbs"]
data_point['total_fat'] = data["total_fat"]
data_point['total_protein'] = data["total_protein"]
data_point['total_sodium'] = data["total_sodium"]
data_point['total_sugar'] = data["total_sugar"]
data_point['total_fiber'] = data["total_fiber"]

data_point = pd.DataFrame(data_point)
data_point
# Out:
#      total_calories  total_carbs  total_fat  total_protein  total_sodium  \
# 0           73701.0       6196.0     2877.0         3379.0       58892.0
# 1          405220.0      39757.0    15061.0        22073.0      357434.0
# 2          400237.0      40230.0    14044.0        22207.0      337045.0
# 3          402535.0      39267.0    14585.0        21971.0      327624.0
# 4          541442.0      53949.0    19930.0        29552.0      467812.0
# ..              ...          ...        ...            ...           ...
# 203        710073.0      66273.0    26095.0        34380.0      631687.0
# 204        745455.0      74221.0    27560.0        42725.0      681933.0
# 205        453123.0      45123.0    17046.0        26786.0      421763.0
# 206        153984.0      14922.0     6191.0         8971.0      154710.0
# 207         16174.0       1685.0      436.0         1025.0       15415.0
#
#      total_sugar  total_fiber
# 0         1915.0        499.0
# ...

# %% [markdown]
# ### ავაგოთ კორელაციების heatmap და დავაკვირდეთ რომელი ელემენტებია ერთმანეთზე მჭიდროდ დამოკიდებული

# %%
correlation_map = data_point.corr()
fig, ax = plt.subplots(figsize=(10,10)) 
sns.heatmap(correlation_map, annot=True, linewidths=.5, ax=ax)
plt.show()

# %% [markdown]
# ავაგოთ violinplot რომელიც გვაჩვენებს კონკრეტული შაგრის რაოდენობისთვის რა ოდენობის ჯამური კალორია იქნება ოსალოდნელი, გრაფიკი ადეკვატურ შედეგს გვაძლევს და გვაჩვენებს რა სავარაუდო მიმართებაა შაქარსა და კალორიას შორის.
#
# #### ეს ერთგვარი წინასწარმეტყველების ილუზიასაც შექმნის რადგან შეგვიძლია მარალი სიზუსტით ვივარაუდოდ კონკრეტული შაქრის მიღების შემთხვევაში მომხმარებელს რა ოდენობის კალორია ექნება მიღებული

# %%
_, ax = plt.subplots(figsize=(17, 8))
sns.violinplot(ax=ax, x="total_sugar", y="total_calories", data=data_point)
plt.title('Distribution of regions, per Sugar probability', fontsize=17)
plt.xticks(rotation=80, fontsize=17)
plt.yticks(fontsize=17)
plt.xlabel('Sugar Value')
plt.ylabel('Calories probability')
plt.show()

# %% [markdown]
# ## Seaborn's jointplot
#
# Seaborn's jointplot displays a relationship between 2 variables (bivariate) as well as 1D profiles (univariate) in the margins. This plot is a convenience class that wraps JointGrid.
#
# The multivariate normal distribution is a nice tool to demonstrate this type of plot as it is sampling from a multidimensional Gaussian and there is natural clustering.
#
# გამოვიყენოთ seaborn's jointplot-ის 3 სახეობა ჩვენს მონაცემებში არსებული წყვილ-წყვილად ორ-ორი ცვლადის კავშირის დასადგენად. ჩვენ გამოვიყენებთ:
#     1.resid
#     2.reg
#     3.scatter
#
# სამივე მოგვცემს კალორიებისა და მისი შემადგენელი "ნუტრიენტების" დამოკიდებუ;ებას განსხვავებული პერსპექტივით

# %%
sns.jointplot(x="total_protein", y="total_calories", data=data_point, kind = 'resid')
sns.jointplot(x="total_carbs", y="total_calories", data=data_point,kind = 'resid')

# %%
sns.jointplot(x="total_sodium", y="total_calories", data=data_point,kind = 'reg')
sns.jointplot(x="total_fiber", y="total_calories", data=data_point,kind = 'reg')

# %%
sns.jointplot(x="total_sugar", y="total_calories", data=data_point,kind = 'scatter')
sns.jointplot(x="total_fat", y="total_calories", data=data_point,kind = 'scatter')

# %% [markdown]
# დავიწყოთ მომხმარებლის მიერ შეყვანილი ჯამური მონაცემების დამუშავება.
#
# total_calories დასამუშავებელი მონაცემებიდან ამოვირეთ რადგან მისი მნიშვნელობა უდრის ჯამურად არებული ყველა სხვა მონაცემის მნიშვნელობას, როგორებიცაა: total_carbs, total_fat, total_protein, total_sodium, total_sugar, total_fiber.
#
# ამისთვის სევქმნათ data_point ეალური დატის დუბლიკატი კალორიების ველის გარეშე

# %%
data_point= {}
data_point['total_carbs'] = data["total_carbs"]
data_point['total_fat'] = data["total_fat"]
data_point['total_protein'] = data["total_protein"]
data_point['total_sodium'] = data["total_sodium"]
data_point['total_sugar'] = data["total_sugar"]
data_point['total_fiber'] = data["total_fiber"]

   
data_point = pd.DataFrame(data_point)
data_point
# Out:
#      total_carbs  total_fat  total_protein  total_sodium  total_sugar  \
# 0         6196.0     2877.0         3379.0       58892.0       1915.0
# 1        39757.0    15061.0        22073.0      357434.0      10789.0
# 2        40230.0    14044.0        22207.0      337045.0       9516.0
# 3        39267.0    14585.0        21971.0      327624.0       9490.0
# 4        53949.0    19930.0        29552.0      467812.0      12474.0
# ..           ...        ...            ...           ...          ...
# 203      66273.0    26095.0        34380.0      631687.0      14119.0
# 204      74221.0    27560.0        42725.0      681933.0      16300.0
# 205      45123.0    17046.0        26786.0      421763.0      10427.0
# 206      14922.0     6191.0         8971.0      154710.0       3206.0
# 207       1685.0      436.0         1025.0       15415.0        318.0
#
#      total_fiber
# 0          499.0
# 1         2113.0
# 2         2265.0
# 3         2246.0
# 4         3510.0
# ...

# %% [markdown]
# დავაკვირდეთ მონაცემების განაწილებას ჩვენს დუბლიკად დატაში. როგორც ვატყობთ მონაცემების 99% და ამავე მონაცემების max მნიშვნელობები საკმაოდ აცდენილია, რაც გვაძლევს იმის საფუძველს რომ 99% წევით მონაცემები ჩავთვალოთ აუთლეიერებად და გადავყაროთ, ან ცავანაცვლოთ 99%-ში გავრცელებული მაქსიმალური მონაცემით, რადგან დავიზღვიოთ თავი ამ აუთლეიერებისგან

# %%
data_point.describe([0.99])
# Out:
#          total_carbs      total_fat  total_protein  total_sodium  \
# count     208.000000     208.000000     208.000000  2.080000e+02
# mean   402465.975962  147793.504808  208415.278846  3.652665e+06
# std    163067.255878   58897.607774   86114.491822  1.510791e+06
# min      1685.000000     436.000000    1025.000000  1.541500e+04
# 50%    417626.000000  149038.500000  215614.000000  3.723360e+06
# 99%    647603.010000  232542.020000  346694.900000  6.058767e+06
# max    861344.000000  339976.000000  353634.000000  6.525403e+06
#
#          total_sugar   total_fiber
# count     208.000000    208.000000
# mean    89363.427885  20931.778846
# std     40546.267692   8398.945831
# min       318.000000     37.000000
# 50%     89447.000000  21769.500000
# 99%    149690.650000  33741.710000
# max    318581.000000  34191.000000

# %%
from sklearn.preprocessing import MinMaxScaler
def normalize(data,col):
    norm = MinMaxScaler().fit(data[[col]])
    data[col] = norm.transform(data[[col]])

# %% [markdown]
# ### გადავუყვეთ მონაცემებს და აუთლეიერები ჩავანაცვლოთ ადეკვატური მნიშვნელობებით

# %%
data_point.filter(data_point['total_carbs']<=647603.010000)
data_point.loc[(data_point['total_carbs']>647603.010000),['total_carbs']] = 647603.010000
data_point.loc[(data_point['total_fat']>232542.020000),['total_fat']] = 232542.020000
data_point.loc[(data_point['total_sodium']>6.058767e+06),['total_sodium']] = 6.058767e+06
data_point.loc[(data_point['total_sugar']>149690.650000),['total_sugar']] = 149690.650000



data_point.describe([0.99])
# Out:
#          total_carbs      total_fat  total_protein  total_sodium  \
# count     208.000000     208.000000     208.000000  2.080000e+02
# mean   401391.384760  147265.591635  208415.278846  3.650349e+06
# std    160745.841333   57645.061816   86114.491822  1.506727e+06
# min      1685.000000     436.000000    1025.000000  1.541500e+04
# 50%    417626.000000  149038.500000  215614.000000  3.723360e+06
# 99%    647521.179300  232417.418600  346694.900000  6.055781e+06
# max    647603.010000  232542.020000  353634.000000  6.058767e+06
#
#          total_sugar   total_fiber
# count     208.000000    208.000000
# mean    88536.898798  20931.778846
# std     37486.881349   8398.945831
# min       318.000000     37.000000
# 50%     89447.000000  21769.500000
# 99%    149683.814500  33741.710000
# max    149690.650000  34191.000000

# %% [markdown]
# დატას თუ შევხედავთ მარტივი მისახვედრია რომ მონაცემებს აუცილებლად დასჭირდებათ ნორმალიზება, რადგან განსხვავება მინიმალურ და მაქსიმალურ მნიშვნელობას  შორის ძალიან დიდია, რაც ხელს შეუშლის და შეუძლებელსაც კი ხდის კლასტერიზაციის ამოცანას.
#
# ამისთვის დავწეროთ ნორმალიზაციის ფუნქცია რომელსაც გადაეცემა სვეტის დასახელება და რომელიც მოახდენს არსებულ დატაში ამ სვეტში არსებული მონაცემების ნორმალიზებას.

# %%
def NormalizeData(data):
    return (data - np.min(data)) / (np.max(data) - np.min(data))

def normalizeDropAndAdd(data, name):
    normalized_age_data = NormalizeData(data[name])
    data[name] = normalized_age_data
    
normalizeDropAndAdd(data_point, 'total_carbs')
normalizeDropAndAdd(data_point, 'total_fat')
normalizeDropAndAdd(data_point, 'total_protein')
normalizeDropAndAdd(data_point, 'total_sodium')
normalizeDropAndAdd(data_point, 'total_sugar')
normalizeDropAndAdd(data_point, 'total_fiber')


data_point.describe()
# Out:
#        total_carbs   total_fat  total_protein  total_sodium  total_sugar  \
# count   208.000000  208.000000     208.000000    208.000000   208.000000
# mean      0.618819    0.632597       0.588159      0.601476     0.590596
# std       0.248864    0.248357       0.244221      0.249320     0.250962
# min       0.000000    0.000000       0.000000      0.000000     0.000000
# 25%       0.458778    0.494351       0.434343      0.443396     0.413690
# 50%       0.643953    0.640235       0.608575      0.613558     0.596689
# 75%       0.793123    0.839085       0.749371      0.805377     0.774673
# max       1.000000    1.000000       1.000000      1.000000     1.000000
#
#        total_fiber
# count   208.000000
# mean      0.611781
# std       0.245914
# min       0.000000
# 25%       0.460268
# 50%       0.636309
# 75%       0.790069
# max       1.000000

# %% [markdown]
# ## გადავიდეთ უშუალოდ კლასტერიზაციაზე
#
# ამისთვის პირველ რიგში დავთვალოთ elbow ფუნქცია, რომელიც გვეუბნება ჩვენი მონაცემებისტვის რამდენი კლასტერის მიღება იქნება ოპტიმალური. ამისთვის გამოვიყენებთ yellowbrick.cluster ბიბლიოტეკას ხოლო უშუალოდ KMeans-სთვის sklearn.cluster-ს

# %%
from sklearn.cluster import KMeans
from yellowbrick.cluster.elbow import kelbow_visualizer
from yellowbrick.cluster import KElbowVisualizer
import plotly.graph_objs as go

# %%
visualizer = kelbow_visualizer(KMeans(random_state=5), data_point, k=(1,40))
visualizer.show()
plt.show()

# %%
n_clusr = 5
kmeans = KMeans(n_clusters=n_clusr).fit(data_point)

for i in range(50):
    kmeans1 = KMeans(n_clusters=n_clusr).fit(data_point)
    if kmeans1.inertia_ < kmeans.inertia_:
        kmeans = kmeans1

# %% [markdown]
# როგორც ვხედავთ KElbowVisualizer მოგვცა 5 კლასტერად დაყოფის რეკომენდაცია, გავუშვით KMeans 5 კლასტერზე და მივიღეთ შემდეგნაირი განაწილება რომელიც sns.countplot-ით გამოგვაქვს.

# %%
sns.countplot(x=kmeans.labels_)
plt.show()

# %%
labels = np.asarray(kmeans.predict(data_point))

# %%
from sklearn.decomposition import PCA
from sklearn import decomposition
from mpl_toolkits.mplot3d import Axes3D

pca = decomposition.PCA(n_components=2)
X_reduced = pca.fit_transform(data_point)

plt.figure(figsize=(5,5))
plt.scatter(X_reduced[:, 0], X_reduced[:, 1],c=labels, cmap=plt.cm.get_cmap('Accent_r', 10))
plt.show()

# %% [markdown]
# გადავამოწმოთ რომ თითოეული მონაცემი გარკვეულ კლასტერში მოხვდა, ამისთვის შევქმნათ ცვენი მონაცემების დუპლიკატი და მივადგატ ახალი სვეტი Cluster#, რომელშიც ჩაიწერება რომელი სტრიქონი რომელ კლასტერში მოხვდა

# %%
copyData = data_point.copy()
labels = np.asarray(kmeans.predict(data_point))
copyData.insert(0, 'Cluster#', labels, True)

# %% [markdown]
# დავაბეჭდინოთ და დავრწმუნდეთ რომ კლასტერები გადანაწილდა ყველა სტრიქონში.

# %%
copyData['Week_Day'] = data["Week_Day"]
copyData
# Out:
#      Cluster#  total_carbs  total_fat  total_protein  total_sodium  \
# 0           3     0.006984   0.010517       0.006676      0.007194
# 1           3     0.058942   0.063010       0.059692      0.056594
# 2           3     0.059675   0.058628       0.060072      0.053220
# 3           3     0.058184   0.060959       0.059403      0.051662
# 4           3     0.080914   0.083987       0.080903      0.074859
# ..        ...          ...        ...            ...           ...
# 203         3     0.099994   0.110549       0.094595      0.101975
# 204         3     0.112299   0.116860       0.118261      0.110289
# 205         3     0.067250   0.071562       0.073058      0.067239
# 206         3     0.020493   0.024795       0.022535      0.023049
# 207         3     0.000000   0.000000       0.000000      0.000000
#
#      total_sugar  total_fiber   Week_Day
# 0       0.010691     0.013527     Sunday
# 1       0.070100     0.060784     Monday
# ...

# %%
sns.countplot('Cluster#', hue='Week_Day', data=copyData);

# %% [markdown]
# მიღებული შედეგებიდან გამომდინარე ცხადად ჩანს რომ შეგვიძლია კლასტერებისთვის კონკრეტული სახელების დარქმევა, რადგან მათში მკაფიოდ გამოიკვეთა გარკვეული დიფერენციები.
#
# კლასტერი 4: ამ კლასტერში მოხვდა მომხმარებელთა ის კატეგორია რომელიც ავლენს ტენდეენციას შაბათ-კვირას ამ აპლიკაციის აქტიური გამოყენების, რაც პირდაპირ კავშირშია მათი კვების რეჟიმის აქტივობასთან.
#
# კლასტერი 0: ადამიანების ის კატეგორია რომელიც ორშაბათს მაქსიმალურად პასიურობენ, თუმცა ნე-ნელა ზრდიან ტემპს და კვირის ბოლოსთვის მაღალ აქტივობას ავლენენ.
#
# კლასტერი 2: ადამიანთა ის კატეგორია რომლებსაც weekend ყველაზე მეტად ახარებთ და პარაკსევს მაქსიმალურად დიდ დროს უთმობენ საკუთარ თავს. თუმცა კვირის დღეებში სტაბილურად თუმცა ნაკლებ-ინტენსიობით იყენებენ აპლიკაციას.
#
# კლასტერი 1: ყველაზე საინტერესო კლასტერი იმ გაგებით რომ weekend-ის არც ერთ წამს არ უთმობენ აპლიკაციას, თუმცა სამუშაო დრეებში აქტიურად აწარმოებენ ამ აპლიკაციაში მონაცემების შეყვანას.
#
# კლასტერი 3: ადამინთა ის კატეგორია რომლებსაც ერთგული მომხმარებლები შეგვიძლია ვუწოდოთ, რადგან ყოველდრე, განურჩევლად სამუშაო თუ არასამუშაო დღისა ისინი სტაბილურად იყენებენ აპლიკაციას.

# %% [markdown]
# ## იგივე პროცედურები ჩავატარეთ აპლიკაციის მიერ დაწესებულ "მიზნებზე" (goal)

# %%
data_point_goals= {}
data_point_goals['goal_carbs'] = data["goal_carbs"]
data_point_goals['goal_fat'] = data["goal_fat"]
data_point_goals['goal_protein'] = data["goal_protein"]
data_point_goals['goal_sodium'] = data["goal_sodium"]
data_point_goals['goal_sugar'] = data["goal_sugar"]
data_point_goals['goal_fiber'] = data["goal_fiber"]

data_point_goals = pd.DataFrame(data_point_goals)
data_point_goals
# Out:
#      goal_carbs  goal_fat  goal_protein  goal_sodium  goal_sugar  goal_fiber
# 0        9058.0    3419.0        6330.0      68500.0      1858.0      1047.0
# 1       52586.0   18085.0       33985.0     406900.0     11154.0      3874.0
# 2       52801.0   17608.0       32824.0     403500.0     11127.0      3857.0
# 3       51505.0   17412.0       32747.0     387400.0     11141.0      3876.0
# 4       68592.0   24019.0       43538.0     559100.0     14571.0      5478.0
# ..          ...       ...           ...          ...         ...         ...
# 203     95594.0   30819.0       60391.0     796050.0     20594.0      6249.0
# 204    109239.0   34863.0       68753.0     896850.0     23351.0      7116.0
# 205     66295.0   21291.0       40880.0     559550.0     14365.0      4147.0
# 206     24746.0    8281.0       15377.0     224400.0      5382.0      1561.0
# 207      3257.0     948.0        1913.0      27700.0       565.0       148.0
#
# [208 rows x 6 columns]

# %%
data_point_goals.describe([0.99])
# Out:
#           goal_carbs       goal_fat   goal_protein   goal_sodium  \
# count     208.000000     208.000000     208.000000  2.080000e+02
# mean   537656.889423  171963.855769  322446.639423  4.358693e+06
# std    210740.716301   66979.873370  124417.285413  1.759624e+06
# min      3257.000000     948.000000    1913.000000  2.770000e+04
# 50%    550938.000000  175908.500000  334804.500000  4.413875e+06
# 99%    859739.730000  271416.110000  508902.020000  7.055366e+06
# max    869339.000000  275627.000000  514647.000000  7.126050e+06
#
#           goal_sugar    goal_fiber
# count     208.000000    208.000000
# mean   114521.687500  35354.745192
# std     47719.241873  12948.992236
# min       565.000000    148.000000
# 50%    113110.000000  37675.500000
# 99%    191395.930000  53822.510000
# max    197483.000000  54484.000000

# %%
normalizeDropAndAdd(data_point_goals, 'goal_carbs')
normalizeDropAndAdd(data_point_goals, 'goal_fat')
normalizeDropAndAdd(data_point_goals, 'goal_protein')
normalizeDropAndAdd(data_point_goals, 'goal_sodium')
normalizeDropAndAdd(data_point_goals, 'goal_sugar')
normalizeDropAndAdd(data_point_goals, 'goal_fiber')


data_point_goals.describe()
# Out:
#        goal_carbs    goal_fat  goal_protein  goal_sodium  goal_sugar  \
# count  208.000000  208.000000    208.000000   208.000000  208.000000
# mean     0.617032    0.622603      0.625146     0.610141    0.578701
# std      0.243327    0.243848      0.242655     0.247892    0.242331
# min      0.000000    0.000000      0.000000     0.000000    0.000000
# 25%      0.481477    0.491114      0.494297     0.461806    0.439759
# 50%      0.632366    0.636964      0.649248     0.617915    0.571532
# 75%      0.806249    0.815478      0.811485     0.814469    0.786397
# max      1.000000    1.000000      1.000000     1.000000    1.000000
#
#        goal_fiber
# count  208.000000
# mean     0.647945
# std      0.238313
# min      0.000000
# 25%      0.514305
# 50%      0.690656
# 75%      0.804835
# max      1.000000

# %%
visualizer = kelbow_visualizer(KMeans(random_state=5), data_point_goals, k=(1,40))
visualizer.show()
plt.show()

# %%
kmeans_goals = KMeans(n_clusters=5).fit(data_point_goals)

for i in range(50):
    kmeans1 = KMeans(n_clusters=5).fit(data_point_goals)
    if kmeans1.inertia_ < kmeans_goals.inertia_:
        kmeans_goals = kmeans1

# %%
sns.countplot(x=kmeans_goals.labels_)
plt.show()

# %%
labels_goals = np.asarray(kmeans_goals.predict(data_point_goals))

# %%
pca = decomposition.PCA(n_components=2)
X_reduced = pca.fit_transform(data_point_goals)

plt.figure(figsize=(5,5))
plt.scatter(X_reduced[:, 0], X_reduced[:, 1],c=labels_goals, cmap=plt.cm.get_cmap('Accent_r', 10))
plt.show()

# %%
goalCopyData = data_point_goals.copy()
labels = np.asarray(kmeans_goals.predict(goalCopyData))
goalCopyData.insert(0, 'Cluster#', labels, True)
goalCopyData['Week_Day'] = data["Week_Day"]

# %%
sns.countplot('Cluster#', hue='Week_Day', data=goalCopyData);

# %% [markdown]
# როგორც ვხედავთ total და goal კლასტერები თითქმის იდენტურია, რაც იმის ვარაუდის საფუძველს გვაძლევს, მომხმარებლები, პატიოსნად თუ არაპატიოსნად, მაქსიმალურად ცდილობენ დაამთხვიონ შეყვანილი მონაცცემები აპლიკაციის დასახულ მონაცემებს. ამისთვის სხვადასხვა ხერხებს იყენებენმ რაც პირველ ფაილში გვაქვს აღწერილი, როგორიცაა breastfeeding და custom adjust მონაცემები, რომლებიც ხშირად უარყოფით კალორიებს მოიცავს, რაც ცალსახად goal-ის დასამთხვევად არის შეყვანილი.

# %% [markdown]
# ### იგივე პროცედურები ჩავატარეთ აპლიკაციის მიერ დაწესებულ "მიზნებზებსა" და მომხმარებლის შეყვანილ მონაცემებს შორის სხვაობაზე, ანუ ბაზის diff სექციაზე.

# %%
data_point_diffs= {}
data_point_diffs['diff_carbs'] = data["diff_carbs"]
data_point_diffs['diff_fat'] = data["diff_fat"]
data_point_diffs['diff_protein'] = data["diff_protein"]
data_point_diffs['diff_sodium'] = data["diff_sodium"]
data_point_diffs['diff_sugar'] = data["diff_sugar"]
data_point_diffs['diff_fiber'] = data["diff_fiber"]

data_point_diffs = pd.DataFrame(data_point_diffs)
data_point_diffs
# Out:
#      diff_carbs  diff_fat  diff_protein  diff_sodium  diff_sugar  diff_fiber
# 0       -2862.0    -542.0       -2951.0      -9608.0        57.0      -548.0
# 1      -12829.0   -3024.0      -11912.0     -49466.0      -365.0     -1761.0
# 2      -12571.0   -3564.0      -10617.0     -66455.0     -1611.0     -1592.0
# 3      -12238.0   -2827.0      -10776.0     -59776.0     -1651.0     -1630.0
# 4      -14643.0   -4089.0      -13986.0     -91288.0     -2097.0     -1968.0
# ..          ...       ...           ...          ...         ...         ...
# 203    -29321.0   -4724.0      -26011.0    -164363.0     -6475.0     -3294.0
# 204    -35018.0   -7303.0      -26028.0    -214917.0     -7051.0     -2948.0
# 205    -21172.0   -4245.0      -14094.0    -137787.0     -3938.0     -1428.0
# 206     -9824.0   -2090.0       -6406.0     -69690.0     -2176.0      -555.0
# 207     -1572.0    -512.0        -888.0     -12285.0      -247.0      -111.0
#
# [208 rows x 6 columns]

# %%
data_point_diffs.describe([0.99])
# Out:
#           diff_carbs      diff_fat   diff_protein   diff_sodium  \
# count     208.000000    208.000000     208.000000  2.080000e+02
# mean  -135190.913462 -24170.350962 -114031.360577 -7.060280e+05
# std     53862.127200  14248.096972   41086.179486  2.749064e+05
# min   -270732.000000 -61922.000000 -199863.000000 -1.179731e+06
# 50%   -136672.500000 -25206.500000 -118087.500000 -7.354175e+05
# 99%     -3349.340000  11802.130000   -6700.770000 -1.488767e+04
# max      1579.000000  96348.000000    -888.000000  2.548240e+05
#
#           diff_sugar    diff_fiber
# count     208.000000    208.000000
# mean   -25158.259615 -14422.966346
# std     15905.145219   4932.439053
# min    -55899.000000 -21165.000000
# 50%    -23127.000000 -15336.500000
# 99%      -255.260000   -616.110000
# max    131168.000000   -111.000000

# %%
visualizer = kelbow_visualizer(KMeans(random_state=5), data_point_diffs, k=(1,40))
visualizer.show()
plt.show()

# %%
kmeans_diffs = KMeans(n_clusters=5).fit(data_point_diffs)

for i in range(50):
    kmeans1 = KMeans(n_clusters=5).fit(data_point_diffs)
    if kmeans1.inertia_ < kmeans_diffs.inertia_:
        kmeans_diffs = kmeans1

# %%
sns.countplot(x=kmeans_diffs.labels_)
plt.show()

# %%
labels_diffs = np.asarray(kmeans_diffs.predict(data_point_diffs))

# %%
pca = decomposition.PCA(n_components=2)
X_reduced = pca.fit_transform(data_point_diffs)

plt.figure(figsize=(10,10))
plt.scatter(X_reduced[:, 0], X_reduced[:, 1],c=labels_diffs, cmap=plt.cm.get_cmap('Accent_r', 10))
plt.show()

# %%
diffCopyData = data_point_diffs.copy()
labels = np.asarray(kmeans_diffs.predict(diffCopyData))
diffCopyData.insert(0, 'Cluster#', labels, True)
diffCopyData['Week_Day'] = data["Week_Day"]
sns.countplot('Cluster#', hue='Week_Day', data=diffCopyData);

# %% [markdown]
# ბოლო ეტაპზე ვნახოთ რა პერიოდში არის მომხმარებლების აქტივობა მაქსიმალური და დავადგინოთ ამის მიზეზი, ასევე გადავამოწმოთ ემთხვევა ტუ არა ეს მაღალი აქტივობა აპლიკაციის მოთხოვნებს.

# %%
data_point= {}
data_point['total_carbs'] = data["total_carbs"]
data_point['total_fat'] = data["total_fat"]
data_point['total_protein'] = data["total_protein"]
data_point['total_sodium'] = data["total_sodium"]
data_point['total_sugar'] = data["total_sugar"]
data_point['total_fiber'] = data["total_fiber"]

data_point = pd.DataFrame(data_point)

# %%
data_point.describe([0.99])
# Out:
#          total_carbs      total_fat  total_protein  total_sodium  \
# count     208.000000     208.000000     208.000000  2.080000e+02
# mean   402465.975962  147793.504808  208415.278846  3.652665e+06
# std    163067.255878   58897.607774   86114.491822  1.510791e+06
# min      1685.000000     436.000000    1025.000000  1.541500e+04
# 50%    417626.000000  149038.500000  215614.000000  3.723360e+06
# 99%    647603.010000  232542.020000  346694.900000  6.058767e+06
# max    861344.000000  339976.000000  353634.000000  6.525403e+06
#
#          total_sugar   total_fiber
# count     208.000000    208.000000
# mean    89363.427885  20931.778846
# std     40546.267692   8398.945831
# min       318.000000     37.000000
# 50%     89447.000000  21769.500000
# 99%    149690.650000  33741.710000
# max    318581.000000  34191.000000

# %%
data_point.filter(data_point['total_carbs']<=647603.010000)
data_point.loc[(data_point['total_carbs']>647603.010000),['total_carbs']] = 647603.010000
data_point.loc[(data_point['total_fat']>232542.020000),['total_fat']] = 232542.020000
data_point.loc[(data_point['total_sodium']>6.058767e+06),['total_sodium']] = 6.058767e+06
data_point.loc[(data_point['total_sugar']>149690.650000),['total_sugar']] = 149690.650000

# %%
data_point.describe([0.99])
# Out:
#          total_carbs      total_fat  total_protein  total_sodium  \
# count     208.000000     208.000000     208.000000  2.080000e+02
# mean   401391.384760  147265.591635  208415.278846  3.650349e+06
# std    160745.841333   57645.061816   86114.491822  1.506727e+06
# min      1685.000000     436.000000    1025.000000  1.541500e+04
# 50%    417626.000000  149038.500000  215614.000000  3.723360e+06
# 99%    647521.179300  232417.418600  346694.900000  6.055781e+06
# max    647603.010000  232542.020000  353634.000000  6.058767e+06
#
#          total_sugar   total_fiber
# count     208.000000    208.000000
# mean    88536.898798  20931.778846
# std     37486.881349   8398.945831
# min       318.000000     37.000000
# 50%     89447.000000  21769.500000
# 99%    149683.814500  33741.710000
# max    149690.650000  34191.000000

# %% [markdown]
# მონაცემებზე დაკვირვებით ამოვირეთ მთელს ბაზაში არსებული მნიშვნელობებიდან მაქსიმალურები და დავადგინეთ თუ რომელ დრეს შეიყვანეს ეს მნიშვნელობები მომხმარებლებმა

# %%
max_dates = []
for i in range(208):
    if(data_point['total_carbs'][i] == 647603.010000):
        print("Max tot Carbs:  "+data['Date'][i])
        max_dates.append(data['Date'][i])
    if(data_point['total_fat'][i] == 232542.020000):
        print("Max tot Fat:  "+data['Date'][i])
        max_dates.append(data['Date'][i])
    if(data_point['total_protein'][i] == 353634.000000):
        max_dates.append(data['Date'][i])
        print("Max tot Prot:  "+data['Date'][i])
    if(data_point['total_sodium'][i] == 6.058767e+06):
        print("Max total_sodium:  "+data['Date'][i]) 
        max_dates.append(data['Date'][i])
    if(data_point['total_sugar'][i] == 149690.650000):
        print("Max total_sugar:  "+data['Date'][i]) 
        max_dates.append(data['Date'][i])
    if(data_point['total_fiber'][i] == 34191.000000):
        print("Max total_fiber:  "+data['Date'][i]) 
        max_dates.append(data['Date'][i])
print(max_dates)
sns.countplot(x=max_dates)
plt.show()
# Out:
# Max total_fiber:  2015-01-13
# Max tot Prot:  2015-01-15
# Max tot Carbs:  2015-01-20
# Max tot Fat:  2015-01-20
# Max total_sodium:  2015-01-20
# Max total_sugar:  2015-01-20
# Max tot Carbs:  2015-01-21
# Max tot Fat:  2015-01-21
# Max total_sodium:  2015-01-21
# Max total_sugar:  2015-01-21
# Max tot Carbs:  2015-01-26
# Max total_sugar:  2015-01-26
# Max total_sodium:  2015-01-28
# Max tot Fat:  2015-01-30
# ['2015-01-13', '2015-01-15', '2015-01-20', '2015-01-20', '2015-01-20', '2015-01-20', '2015-01-21', '2015-01-21', '2015-01-21', '2015-01-21', '2015-01-26', '2015-01-26', '2015-01-28', '2015-01-30']

# %% [markdown]
# როგორც ვხედავთ მარალი აქტიობა და ასევე შეყვანილი მაქსიმალური მნიშვნელობები არის 2015 წლის იანვარში, კონკრეტულად კი 15-30 იანვრის დიაპაზონში. In[4]-ში ჩატარებულ მშჯელობას თუ გავიხსენებთ აღმოვაჩენთ რომ 14 სექტემბრიდან 100-105 დღეში სწორედ ცავარდნის პერიოდია რომელიც ემთხვევა შობა-ახალ წელს, და როგორც ხდება ხოლმე და როგორც მოსალოდნელია ახალი წლის შემდეგ ადამიანები უბრუნდებიან ჯანსაღ კვებას, სპორტულ ცხოვრებას და ა.შ და ეს აქტიურობაც მაგით აიხსნება. არდადეგების და სახლში ჯდომის შემდეგ ხალხი დაუბრუნდა რეჟიმს, და აპლიკაციის კვლავ გამოყენებაც მაგით აიხსნება.
#
# ამითვე აიხსნება 20-21-ში მაქსიმალური მნიშვნელობების შეყვანა. მომხმარებლებმა განაახლეს აპლიკაციის გამოყენება თუმცა ჯერ კიდევ იმ რეჟიმით აგრძელებენ კვებას როგორითაც საშობაო არდადეგებზე იკვებებოდნენ. ეს პერიოდი სწორედ ის გარდამტეხი მომენტია როდესაც აპლიკაციის გამოყენებას იწყენ/ანახლებ, მაგრამ 1-2 cheating day გაქვს, მერე კი როგორც გრაფიკზე ვხედავთ სიტუაცია სტაბილურდება და მომდევნო 2 თვე მომხმარებლები რეჟიმს ინარჩუნებენ.

# %%
data_point_goals= {}
data_point_goals['goal_carbs'] = data["goal_carbs"]
data_point_goals['goal_fat'] = data["goal_fat"]
data_point_goals['goal_protein'] = data["goal_protein"]
data_point_goals['goal_sodium'] = data["goal_sodium"]
data_point_goals['goal_sugar'] = data["goal_sugar"]
data_point_goals['goal_fiber'] = data["goal_fiber"]


data_point_goals = pd.DataFrame(data_point_goals)
data_point_goals.describe([0.99])
# Out:
#           goal_carbs       goal_fat   goal_protein   goal_sodium  \
# count     208.000000     208.000000     208.000000  2.080000e+02
# mean   537656.889423  171963.855769  322446.639423  4.358693e+06
# std    210740.716301   66979.873370  124417.285413  1.759624e+06
# min      3257.000000     948.000000    1913.000000  2.770000e+04
# 50%    550938.000000  175908.500000  334804.500000  4.413875e+06
# 99%    859739.730000  271416.110000  508902.020000  7.055366e+06
# max    869339.000000  275627.000000  514647.000000  7.126050e+06
#
#           goal_sugar    goal_fiber
# count     208.000000    208.000000
# mean   114521.687500  35354.745192
# std     47719.241873  12948.992236
# min       565.000000    148.000000
# 50%    113110.000000  37675.500000
# 99%    191395.930000  53822.510000
# max    197483.000000  54484.000000

# %%
max_dates = []
for i in range(208):
    if(data_point_goals['goal_carbs'][i] == 869339.000000):
        print("Max goal_carbs:  "+data['Date'][i])
        max_dates.append(data['Date'][i])
    if(data_point_goals['goal_fat'][i] == 275627.000000):
        print("Max goal_fat:  "+data['Date'][i])
        max_dates.append(data['Date'][i])
    if(data_point_goals['goal_protein'][i] == 514647.000000):
        max_dates.append(data['Date'][i])
        print("Max goal_protein:  "+data['Date'][i])
    if(data_point_goals['goal_sodium'][i] == 7.126050e+06):
        print("Max total_sodium:  "+data['Date'][i]) 
        max_dates.append(data['Date'][i])
    if(data_point_goals['goal_sugar'][i] == 197483.000000):
        print("Max goal_sugar:  "+data['Date'][i]) 
        max_dates.append(data['Date'][i])
    if(data_point_goals['goal_fiber'][i] == 54484.000000):
        print("Max goal_fiber:  "+data['Date'][i]) 
        max_dates.append(data['Date'][i])
print(max_dates)
sns.countplot(x=max_dates)
plt.show()
# Out:
# Max goal_protein:  2015-01-12
# Max goal_fiber:  2015-01-12
# Max goal_carbs:  2015-01-20
# Max goal_fat:  2015-01-20
# Max total_sodium:  2015-01-20
# Max goal_sugar:  2015-02-09
# ['2015-01-12', '2015-01-12', '2015-01-20', '2015-01-20', '2015-01-20', '2015-02-09']

# %% [markdown]
# არაა გასაკვირი რომ სწორედ ამ პერიოდს ემთხვევა goal-ებზე ჩატარებული დაკვირვების შედეგიც, რადგან მკვეთრად მოიმატა მომხმარებლების რიცხვი, ასევე მათი არაჯანსაჟი კვებითი რეჟიმი და აპლიკაციაც 12-30 იანვრის დიაპაზონსი ყველაზე მაღალ goal-ს აწესებდა, რადგან მომხმარებლისტვის პირდაპი 2000 ან 1500 კალორიის დაწესება სტესული არ ყოფილიყო, არაჯანსაღი ახალიწლის 5000 კალორიის შემდეგ

# %% [markdown]
# ## საბოლოოდ მთელი პროცესი რომ შევაჯამოთ , იგი შეგვიძლია დავყოთ რამდენიმე ეტაპად:
#     1)მონაცემების წაკითხვა/გააზრება- საკმაოდ დიდი დრო წაიღო მონაცემთა გააზრებამ, მისი სიდიდისა და მოცულობიდან გამომდინარე. თითოეული ჩანაწერის მოცულობა და მათში გადმოცემული ინფორმაციის აღქმა საკმაოდ შრომატევადი პროცესი იყო .
#     2) მონაცემების გაფილტვრა - მოცემული 2.1გბ_იანი მონაცემები ძალიან დიდი იყო სამუშაოდ და მრავალ არასაჭირო ინფორმაციას შეიცავდა. შესაბამისად გადავწყვიტეთ მისი ისე გაფილტვრა, რომ აზრობრივი დანაკარგი ყოფილიყო მინიმალური და მაქსიმალურად შემცირებულიყო ზომაში. ამასთანავე ამ პროცესში გამოიკვეთა აზრი , რომ მონაცემები უნდა განგვეხილა დროის ჭრილში და ნაკლები ყურადღება უნდა დაგვეთმო მათ იუზერთა ჭრილში განხილვისთვის . დროის ჭრილში განხილვამ მოგვცა საშუალება, ახალი დატაფრეიმი ყოფილიყო ბევრად უფრო გასაგები , დალაგებული და მაქსიმალურად ზომაში შემცირებული , მინიმალური მონაცემობრივი დანაკარგით. ამ პროცესში არარეთი საინტერესო მიგნება გვქონდა . მაგალითად დივერგენციების რაოდენობები, უარყოფითი მნიშვნელობის მქონე მონაცემები , არასერიოზული მონაცემების არაერთი შემთხვევა და სხვ.
#     3) მიღებული დატაფრეიმის დამუშავება - 2 ნაბიჯის შემდეგ მიღებული 208xY განზომილების მონაცემებზე დავიწყეთ გარკვეული კალკულაციების ჩატარება . განვსაზღვრეთ აუტლაიერები და შეძლებისდაგვარად მოვაშორეთ ისინი. მონაცემებს ვჭრიდით პატარ-პატარა ფრეიმებად , რათა უფრო მარტივი ყოფილიყო მათზე ოპერაციების ჩატარება . პროცესში გამოვიყენეთ sklearn.cluster ბიბლიოთეკის K-Means კლასტერიზაციის ალგორითმი და yellowbrick.cluster ბიბლიოთეკის elbow ფუნქცია,რათა ოპტიმალურად გაგვეგო ოპტიმალური კლასტერების რაოდენობა და შემდეგ ოპტიმალურად შეგვესრულებინა თვითონ მონაცემთა კლასტერიზაცია. კლასტერიზაცია გავაკეთეთ რამოდენიმე ტიპის მონაცემთა ჯგუფებზე
#     4) დაკლასტერებულ მონაცემთა ანალიზი - რამოდენიმე სეგმენტად დაყოფილი კლასტერები ტიპების მიხედვით შევადარეთ ერთმანეთს. დაკვირვებების შედეგად ვნახეთ მათ შორის მსგავსება-განსხვავებები, რამაც საშუალება მოგვცა ჩამოგვეყალიბებინა მომხმარებელთა ქცევის გარკვეული სურათი, რომელიც საშუალებას გვაძლევს, როგორც გავაუმჯობესოთ აპლიკაციის ქცევა,  ასევე ვივარაუდოთ ახალ მომხმარებელთა დინამიკა და ქმედებები.
#     5) მოცემული დროის მონაკვეთში კრიტიკული დღეების დადგენა - მიღებული ინფორმაციით საშუალება მოგვეცა დაგვედგინა, მოცემული დროისთვის , კრიტიკული პერიოდი . როგორც ვვარაუდობდით,  ეს იყო ზამთრის პერიოდი , ახალი წლების შემდეგი კვირა,როდესაც ყველაზე დიდი რაოდენობის ნუტრიენტების ინფუთი გვქონდა მონაცემებში. ამასთანავე დინამიკის ანალიზით დავადგინეთ, რომ შემოდგომის პერიოდში დაწყებული დინამიკა იუზერებისა, ნელნელა მცირდებოდა ზამთრამდე, შემდეგ გვქონდა მკვეთრი მატება , ხოლო უკვე ზაფხულისკენ კვლავ კლება . მსგავსი ქცევაც საინტერესოა და ინფორმაციას გვაძლევს , როგორც მომხარებელთა ინტერესზე დროის გარკვეულ პერიოდში აპლიკაციისადმი , ასევე მსგავსი აპლიკაციებისთვის პროდაქშენში ჩაშვების საუკეთესო დროის მონაკვეთს.
